# %% [markdown]
# # CSV consolidation

# %% [markdown]
# ## Description
#
# The point of this script is to list all the CSV of a directory, concatenate them in one dataframe and export the  consolidated data in a new CSV.

# %%
# Library importation

import pandas as pd
from os import listdir
from os.path import isfile, join

# %%
# Declaration of variables 
import_path = "/home/exalis/VELIB-DATA/2020_01_16"
export_path = "/home/exalis/VELIB-DATA/"
export_name = "consolidated_dataset_2020_01_16.csv"

# %%
# List of Files
list_of_files = [f for f in listdir(import_path) if isfile(join(import_path, f))]
print("number of files:", len(list_of_files))
# Out:
# number of files: 1438

# %%
# Initialisation of consolidated dataframe with first csv of the list

df_conso = pd.read_csv(import_path+"/"+list_of_files[0],sep="%")

# Addition of notion of date
df_conso['date']= list_of_files[0][:-4]

# Conservation of only headers
df_conso = df_conso[0:0]

# %%
# Each csv is loaded, processed and addated to consolidated dataframe
pd.options.display.max_rows = 5

for i in range(len(list_of_files)):
    df_temp = pd.read_csv(import_path+"/"+list_of_files[i],sep="%")
    # Addition of the date / name of the file
    df_temp['date']= list_of_files[i][:-4]
    df_conso = pd.concat([df_conso,df_temp])
    print("{}/{} ({}%) : {}".format(i,len(list_of_files),round(i/len(list_of_files)*100,1),list_of_files[i]))
# Out:
# 0/1438 (0.0%) : 2020_01_16_10:11:04.csv
# 1/1438 (0.1%) : 2020_01_16_14:18:04.csv
# 2/1438 (0.1%) : 2020_01_16_22:20:01.csv
# 3/1438 (0.2%) : 2020_01_16_21:43:01.csv
# 4/1438 (0.3%) : 2020_01_16_09:08:03.csv
# 5/1438 (0.3%) : 2020_01_16_07:35:04.csv
# 6/1438 (0.4%) : 2020_01_16_16:58:01.csv
# 7/1438 (0.5%) : 2020_01_16_02:28:01.csv
# 8/1438 (0.6%) : 2020_01_16_18:35:01.csv
# 9/1438 (0.6%) : 2020_01_16_05:29:01.csv
# 10/1438 (0.7%) : 2020_01_16_21:06:01.csv
# 11/1438 (0.8%) : 2020_01_16_21:37:01.csv
# 12/1438 (0.8%) : 2020_01_16_13:24:04.csv
# 13/1438 (0.9%) : 2020_01_16_05:17:01.csv
# 14/1438 (1.0%) : 2020_01_16_02:43:01.csv
# 15/1438 (1.0%) : 2020_01_16_02:38:01.csv
# 16/1438 (1.1%) : 2020_01_16_18:40:01.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-4e774549612f> in <module>
#       6     # Addition of the date / name of the file
#       7     df_temp['date']= list_of_files[i][:-4]
# ----> 8     df_conso = pd.concat([df_conso,df_temp])
#       9     print("{}/{} ({}%) : {}".format(i,len(list_of_files),round(i/len(list_of_files)*100,1),list_of_files[i]))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     333
#     334             # consolidate
# --> 335             obj._consolidate(inplace=True)
#     336             ndims.add(obj.ndim)
#     337
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _consolidate(self, inplace)
#    5268         inplace = validate_bool_kwarg(inplace, "inplace")
#    5269         if inplace:
# -> 5270             self._consolidate_inplace()
#    5271         else:
#    5272             f = lambda: self._data.consolidate()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _consolidate_inplace(self)
#    5250             self._data = self._data.consolidate()
#    5251
# -> 5252         self._protect_consolidate(f)
#    5253
#    5254     def _consolidate(self, inplace=False):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _protect_consolidate(self, f)
#    5239         """
#    5240         blocks_before = len(self._data.blocks)
# -> 5241         result = f()
#    5242         if len(self._data.blocks) != blocks_before:
#    5243             self._clear_item_cache()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in f()
#    5248
#    5249         def f():
# -> 5250             self._data = self._data.consolidate()
#    5251
#    5252         self._protect_consolidate(f)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in consolidate(self)
#     930         bm = self.__class__(self.blocks, self.axes)
#     931         bm._is_consolidated = False
# --> 932         bm._consolidate_inplace()
#     933         return bm
#     934
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in _consolidate_inplace(self)
#     935     def _consolidate_inplace(self):
#     936         if not self.is_consolidated():
# --> 937             self.blocks = tuple(_consolidate(self.blocks))
#     938             self._is_consolidated = True
#     939             self._known_consolidated = True
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in _consolidate(blocks)
#    1911     for (_can_consolidate, dtype), group_blocks in grouper:
#    1912         merged_blocks = _merge_blocks(
# -> 1913             list(group_blocks), dtype=dtype, _can_consolidate=_can_consolidate
#    1914         )
#    1915         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3338
#    3339         argsort = np.argsort(new_mgr_locs)
# -> 3340         new_values = new_values[argsort]
#    3341         new_mgr_locs = new_mgr_locs[argsort]
#    3342
#
# KeyboardInterrupt:

# %%
df_conso.head()
# Out:
#    Nombre de bornes disponibles  Nombre vélo en PARK+  \
# 0                            31                     0
# 1                            49                     0
# 2                            20                     0
# 3                            18                     0
# 4                            27                     0
#
#    Nombres de bornes en station PARK + activation  densityLevel  \
# 0                            35                no             1
# 1                            52                no             1
# 2                            21                no             1
# 3                            20                no             1
# 4                            30                no             1
#
#   Achat possible en station (CB)  \
# 0                             no
# 1                            yes
# 2                            yes
# 3                             no
# 4                             no
#
#                                  Description station  maxBikeOverflow  \
# 0  {"code": "16107", "name": "Benjamin Godard - V...                0
# 1  {"code": "6015", "name": "André Mazet - Saint-...               55
# 2  {"code": "9020", "name": "Toudouze - Clauzel",...               21
# 3  {"code": "11104", "name": "Charonne - Robert e...                0
# 4  {"code": "12109", "name": "Mairie du 12ème", "...               30
#
#   Etat du Totem  nbFreeDock  ...  nbDock Nombre vélo électrique  \
# 0           yes           0  ...       0                      2
# 1           yes           2  ...       3                      0
# 2           yes           0  ...       0                      1
# 3           yes           0  ...       0                      1
# 4           yes           0  ...       0                      3
#
#    Nombre vélo en PARK+.1  Code de la station  \
# 0                       0               16107
# 1                       0                6015
# 2                       0                9020
# 3                       0               11104
# 4                       0               12109
#
#                      Nom de la station  Etat des stations Type de stations  \
# 0        Benjamin Godard - Victor Hugo          Operative              yes
# 1   André Mazet - Saint-André des Arts          Operative              yes
# 2                   Toudouze - Clauzel          Operative              yes
# 3  Charonne - Robert et Sonia Delauney          Operative              yes
# 4                      Mairie du 12ème          Operative              yes
#
#                            geo     duedate                 date
# 0           48.865983,2.275725  2018-07-15  2020_01_16_10:11:04
# 1  48.8537558106,2.33909580857  2018-04-05  2020_01_16_10:11:04
# 2  48.8792959173,2.33736008406  2018-11-30  2020_01_16_10:11:04
# 3   48.855907556,2.39257067442  2018-10-22  2020_01_16_10:11:04
# 4  48.8408553118,2.38755494356  2019-03-28  2020_01_16_10:11:04
#
# [5 rows x 22 columns]

# %%
# Last data processing before export

# Deleting "Park + activation"
del df_conso["PARK + activation"]

# Deleting "Description station"
del df_conso["Description station"]

# %%
# Export of the consolidated dataframe

df_conso.to_csv(export_path+"/"+export_name)
